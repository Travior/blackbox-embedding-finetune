# %%
import torch
import pickle as pkl
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
from dataclasses import dataclass
from typing import Optional

@dataclass
class Question:
    question: str
    context_index: int
    embedding: torch.Tensor
    transformed_embedding: torch.Tensor

@dataclass
class Context:
    context: str
    context_index: int
    embedding: torch.Tensor
    transformed_embedding: torch.Tensor



@dataclass
class EmbeddedQuestion(Question):
    embedding: torch.Tensor

@dataclass
class EmbeddedContext(Context):
    embedding: torch.Tensor

    def __hash__(self) -> int:
        return hash(self.context_index)

    def __eq__(self, value: object) -> bool:
        return self.context_index == value.context_index

@dataclass
class DataCollection:
    questions: list[EmbeddedQuestion]
    contexts: list[Context]
    metadata: dict

# %%
def get_most_relevant_contexts(question: list[Question], n_results, use_transformed = True, index_context_map: dict[int, Context] = {}, only_query=False):
    res = []
    contexts: list[Context] = []
    for q in question:
        if index_context_map[q.context_index] not in contexts:
            contexts.append(index_context_map[q.context_index])
    if use_transformed:
        qs = [q.transformed_embedding.numpy() for q in question]
        if not only_query:
            cs = [c.transformed_embedding.numpy() for c in contexts]
        else:
            cs = cs = [c.embedding.numpy() for c in contexts]
    else:
        qs = [q.embedding.numpy() for q in question]
        cs = [c.embedding.numpy() for c in contexts]
    sims = cosine_similarity(np.array(qs), np.array(cs))
    for sim in sims:
        indices = sim.argsort()[-n_results:]
        temp = []
        for index in indices:
            temp.append(contexts[index])
        res.append(temp)
    return res

def get_correct_top_n(questions, index_context_map, n_result, use_transformed, only_query=False):
    eval = []
    most_relevant = get_most_relevant_contexts(questions, n_result, use_transformed, index_context_map, only_query)
    for question, contexts in zip(questions, most_relevant):
        eval.append(index_context_map[question.context_index] in contexts)
    return np.mean(eval)

def get_avg_correct_similarity(questions: list[EmbeddedQuestion], index_context_map, use_transformed=True, only_query=False):
    sims = []
    for question in questions:
        if use_transformed:
            if only_query:
                sims.append(cosine_similarity(question.transformed_embedding.numpy().reshape(1,-1), index_context_map[question.context_index].embedding.reshape(1,-1)).flatten()[0])
            else:
                sims.append(cosine_similarity(question.transformed_embedding.numpy().reshape(1,-1), index_context_map[question.context_index].transformed_embedding.reshape(1,-1)).flatten()[0])
        else:
            sims.append(cosine_similarity(question.embedding.numpy().reshape(1,-1), index_context_map[question.context_index].embedding.reshape(1,-1)).flatten()[0])
    return np.mean(sims)

def get_avg_wrong_similarity(questions: list[EmbeddedQuestion], index_context_map, use_transformed = True, only_query=False):
    sims = []
    contexts = set([index_context_map[q.context_index] for q in questions])
    for question in questions:
        
        if use_transformed:
            if only_query:
                wrong_context_embs = [c.embedding for c in filter(lambda x: x.context_index != question.context_index, contexts)]
                res = cosine_similarity(question.transformed_embedding.numpy().reshape(1,-1), np.array(wrong_context_embs)).flatten().tolist()
            else:
                wrong_context_embs = [c.transformed_embedding for c in filter(lambda x: x.context_index != question.context_index, contexts)]
                res = cosine_similarity(question.transformed_embedding.numpy().reshape(1,-1), np.array(wrong_context_embs)).flatten().tolist()
        else:
            wrong_context_embs = [c.embedding for c in filter(lambda x: x.context_index != question.context_index, contexts)]
            res = cosine_similarity(question.embedding.numpy().reshape(1,-1), np.array(wrong_context_embs)).flatten().tolist()
        sims += res
    return np.mean(sims)            

def get_avg_correct_position(questions: list[EmbeddedQuestion], index_context_map, use_transformed = True, only_query=False):
    contexts = []
    index_context_local_map = {}
    for question in questions:
        if index_context_map[question.context_index] not in contexts:
            index_context_local_map[question.context_index] = len(contexts)
            contexts.append(index_context_map[question.context_index])

    mrrs = []
    if use_transformed:
        if only_query:
            context_embs = [c.embedding for c in contexts]
        else:
            context_embs = [c.transformed_embedding for c in contexts]
        for question in questions:
            indices = cosine_similarity(question.transformed_embedding.numpy().reshape(1,-1), np.array(context_embs)).flatten().argsort().tolist()[::-1]
            index = indices.index(index_context_local_map[question.context_index])
            if index != -1:
                mrrs.append(1/(index+1))
    else:
        context_embs = [c.embedding for c in contexts]
        for question in questions:
            indices = cosine_similarity(question.embedding.numpy().reshape(1,-1), np.array(context_embs)).flatten().argsort().tolist()[::-1]
            index = indices.index(index_context_local_map[question.context_index])
            if index != -1:
                mrrs.append(1/(index+1))
    return np.mean(mrrs)
            
def get_avg_distance_to_first_wrong(questions, index_context_map, use_transformed = True, only_query=False):
    distances = []
    contexts = []
    index_context_local_map = {}
    for question in questions:
        if index_context_map[question.context_index] not in contexts:
            index_context_local_map[question.context_index] = len(contexts)
            contexts.append(index_context_map[question.context_index])
    
    if use_transformed:
        if only_query:
            context_embs = [c.embedding for c in contexts]
        else:
            context_embs = [c.transformed_embedding for c in contexts]
        for question in questions:
            sims = cosine_similarity(question.transformed_embedding.numpy().reshape(1,-1), np.array(context_embs)).flatten().tolist()
            indices = cosine_similarity(question.transformed_embedding.numpy().reshape(1,-1), np.array(context_embs)).flatten().argsort().tolist()[::-1]
            index = indices.index(index_context_local_map[question.context_index])
            if index == 0:
                distances.append(sims[index_context_local_map[question.context_index]] - sims[indices[1]])
            else:
                distances.append(sims[index_context_local_map[question.context_index]] - sims[indices[0]])
    else:
        context_embs = [c.embedding for c in contexts]
        for question in questions:
            sims = cosine_similarity(question.embedding.numpy().reshape(1,-1), np.array(context_embs)).flatten().tolist()
            indices = cosine_similarity(question.embedding.numpy().reshape(1,-1), np.array(context_embs)).flatten().argsort().tolist()[::-1]
            index = indices.index(index_context_local_map[question.context_index])
            if index == 0:
                distances.append(sims[index_context_local_map[question.context_index]] - sims[indices[1]])
            else:
                distances.append(sims[index_context_local_map[question.context_index]] - sims[indices[0]])
    
    return np.mean(distances)

def get_class_result(questions, index_context_map, use_transformed = True):
    contexts = []
    index_context_local_map = {}
    for question in questions:
        if index_context_map[question.context_index] not in contexts:
            index_context_local_map[question.context_index] = len(contexts)
            contexts.append(index_context_map[question.context_index])
    if use_transformed:
        context_embs = [c.transformed_embedding for c in contexts]
        for question in questions:
            sims = cosine_similarity(question.transformed_embedding.numpy().reshape(1,-1), np.array(context_embs)).flatten().tolist()
            for sim in sims:
                pass

# %%
experiment_names = ["expanded-transform", "dimensionality-reduction", "single-layer-squared-0.2-dropout-long-train-low-margin", "single-layer-squared-no-dropout-long-train-low-margin"]

# %%
model_names = ["BAAI-bge-small-en-v1.5", "Cohere-embed-english-v3.0", "text-embedding-3-large", "text-embedding-ada-002"]

# %%
from glob import glob
import pathlib

class_deltas = []
mrr_deltas = []
distance_deltas = []
result_df_entries = []
for experiment_name in experiment_names:
    for model_name in model_names:
        for dataset in list(glob(f"./data/train_experiments/{experiment_name}/{model_name}/*.pkl")):
            print(dataset)
            dataset_name = pathlib.Path(dataset).name.replace(".pkl", "")
            # if "dolly" not in dataset and "sciq" not in dataset:
                # continue
            with open(dataset, "rb") as file:
                collection: DataCollection = pkl.load(file)
                print(len(collection.questions))
                index_context_map = {c.context_index:c for c in collection.contexts}
                acc_1_trans = get_correct_top_n(questions=collection.questions, index_context_map=index_context_map, n_result=1, use_transformed=True, only_query=False)
                acc_1_orig = get_correct_top_n(questions=collection.questions, index_context_map=index_context_map, n_result=1, use_transformed=False, only_query=False)
                acc_3_trans = get_correct_top_n(questions=collection.questions, index_context_map=index_context_map, n_result=3, use_transformed=True, only_query=False)
                acc_3_orig = get_correct_top_n(questions=collection.questions, index_context_map=index_context_map, n_result=3, use_transformed=False, only_query=False)
                acc_5_trans = get_correct_top_n(questions=collection.questions, index_context_map=index_context_map, n_result=5, use_transformed=True, only_query=False)
                acc_5_orig = get_correct_top_n(questions=collection.questions, index_context_map=index_context_map, n_result=5, use_transformed=False, only_query=False)
                mrr_trans = get_avg_correct_position(questions=collection.questions, index_context_map=index_context_map, use_transformed=True, only_query=False)
                mrr_orig = get_avg_correct_position(questions=collection.questions, index_context_map=index_context_map, use_transformed=False, only_query=False)
                distance_to_first_wrong_trans = get_avg_distance_to_first_wrong(collection.questions, index_context_map, True, False)
                distance_to_first_wrong_orig = get_avg_distance_to_first_wrong(collection.questions, index_context_map, False, False)
                distance_deltas.append(distance_to_first_wrong_trans - distance_to_first_wrong_orig)
                class_deltas.append(acc_1_trans-acc_1_orig)
                mrr_deltas.append(mrr_trans-mrr_orig)
                print("Correct percentage:",acc_1_trans, acc_1_orig)
                # print("Avg correct sim:", get_avg_correct_similarity(collection.questions, index_context_map, True), get_avg_correct_similarity(collection.questions, index_context_map, False, False))
                # print("Avg wrong sim:", get_avg_wrong_similarity(collection.questions, index_context_map, True), get_avg_wrong_similarity(collection.questions, index_context_map, False, False))
                print("Avg distance:", distance_to_first_wrong_trans, distance_to_first_wrong_orig)
            result_df_entries.append({"experiment_name":experiment_name,"model_name":model_name, "dataset":dataset_name, "top_1_accuracy_trans":acc_1_trans, "top_1_accuracy_orig":acc_1_orig, "top_3_accuracy_trans":acc_3_trans,"top_3_accuracy_orig":acc_3_orig,"top_5_accuracy_trans":acc_5_trans,"top_5_accuracy_orig":acc_5_orig,
                                      "mrr_trans": mrr_trans, "mrr_orig":mrr_orig, "distance_to_first_wrong_trans":distance_to_first_wrong_trans, "distance_to_first_wrong_orig":distance_to_first_wrong_orig})

print(np.mean(class_deltas), np.std(class_deltas))
print(np.mean(mrr_deltas), np.std(mrr_deltas))
print(np.mean(distance_deltas), np.std(distance_deltas))
# Out:
# ./data/train_experiments/expanded-transform/BAAI-bge-small-en-v1.5/2008_Sichuan_earthquake.pkl
# 74
# Correct percentage: 0.8918918918918919 0.8918918918918919
# Avg distance: 0.13760679562550945 0.06238058692700154
# ./data/train_experiments/expanded-transform/BAAI-bge-small-en-v1.5/Antarctica.pkl
# 35
# Correct percentage: 0.8857142857142857 0.8857142857142857
# Avg distance: 0.21729212360722677 0.09441999367305211
# ./data/train_experiments/expanded-transform/BAAI-bge-small-en-v1.5/Beyoncé.pkl
# 117
# Correct percentage: 0.8632478632478633 0.7948717948717948
# Avg distance: 0.14216968179163006 0.05112811158864926
# ./data/train_experiments/expanded-transform/BAAI-bge-small-en-v1.5/dolly.pkl
# 266
# Correct percentage: 0.9774436090225563 0.9699248120300752
# Avg distance: 0.30644593466269343 0.18065410157791653
# ./data/train_experiments/expanded-transform/BAAI-bge-small-en-v1.5/Frédéric_Chopin.pkl
# 136
# Correct percentage: 0.8897058823529411 0.7941176470588235
# Avg distance: 0.15169186055358938 0.05070231000290198
# ./data/train_experiments/expanded-transform/BAAI-bge-small-en-v1.5/Hunting.pkl
# 60
# Correct percentage: 0.8833333333333333 0.8833333333333333
# Avg distance: 0.20321380871658523 0.08855445484320322
# ./data/train_experiments/expanded-transform/BAAI-bge-small-en-v1.5/Pharmaceutical_industry.pkl
# 54
# Correct percentage: 0.9259259259259259 0.9259259259259259
# Avg distance: 0.27295170358761595 0.1209840906990899
# ./data/train_experiments/expanded-transform/BAAI-bge-small-en-v1.5/sciq-large.pkl
# 1500
# Correct percentage: 0.8106666666666666 0.8093333333333333
# Avg distance: 0.12925459030022224 0.06807315768798192
# ./data/train_experiments/expanded-transform/BAAI-bge-small-en-v1.5/sciq.pkl
# 300
# Correct percentage: 0.94 0.93
# Avg distance: 0.24470370415598153 0.1289899475375811
# ./data/train_experiments/expanded-transform/Cohere-embed-english-v3.0/2008_Sichuan_earthquake.pkl
# 74
# Correct percentage: 0.8648648648648649 0.9054054054054054
# Avg distance: 0.16030395484051188 0.12105252533345609
# ./data/train_experiments/expanded-transform/Cohere-embed-english-v3.0/Antarctica.pkl
# 35
# Correct percentage: 0.9142857142857143 0.9142857142857143
# Avg distance: 0.2621268392673561 0.16348790526390075
# ./data/train_experiments/expanded-transform/Cohere-embed-english-v3.0/Beyoncé.pkl
# 117
# Correct percentage: 0.8974358974358975 0.9145299145299145
# Avg distance: 0.1882029791545664 0.10894423022738889
# ./data/train_experiments/expanded-transform/Cohere-embed-english-v3.0/dolly.pkl
# 266
# Correct percentage: 0.9774436090225563 0.9736842105263158
# Avg distance: 0.3405422475889213 0.29939392483548116
# ./data/train_experiments/expanded-transform/Cohere-embed-english-v3.0/Frédéric_Chopin.pkl
# 136
# Correct percentage: 0.8529411764705882 0.9117647058823529
# Avg distance: 0.18095912192674243 0.09806839793043978
# ./data/train_experiments/expanded-transform/Cohere-embed-english-v3.0/Hunting.pkl
# 60
# Correct percentage: 0.9166666666666666 0.95
# Avg distance: 0.22728837948913375 0.15200774172941844
# ./data/train_experiments/expanded-transform/Cohere-embed-english-v3.0/Pharmaceutical_industry.pkl
# 54
# Correct percentage: 0.9814814814814815 1.0
# Avg distance: 0.2999040793834461 0.20984599849692098
# ./data/train_experiments/expanded-transform/Cohere-embed-english-v3.0/sciq-large.pkl
# 1500
# Correct percentage: 0.8426666666666667 0.842
# Avg distance: 0.13378691377987464 0.10690912358959516
# ./data/train_experiments/expanded-transform/Cohere-embed-english-v3.0/sciq.pkl
# 300
# Correct percentage: 0.9466666666666667 0.9466666666666667
# Avg distance: 0.2461944256660839 0.19893760671218236
# ./data/train_experiments/expanded-transform/text-embedding-3-large/2008_Sichuan_earthquake.pkl
# 74
# Correct percentage: 0.8378378378378378 0.8918918918918919
# Avg distance: 0.1236734273151268 0.1009010062427134
# ./data/train_experiments/expanded-transform/text-embedding-3-large/Antarctica.pkl
# 35
# Correct percentage: 0.8857142857142857 0.8571428571428571
# Avg distance: 0.2567080239366208 0.17459146891321456
# ./data/train_experiments/expanded-transform/text-embedding-3-large/Beyoncé.pkl
# 117
# Correct percentage: 0.8547008547008547 0.8803418803418803
# Avg distance: 0.166038842808105 0.10760460068018009
# ./data/train_experiments/expanded-transform/text-embedding-3-large/dolly.pkl
# 266
# Correct percentage: 0.9736842105263158 0.9736842105263158
# Avg distance: 0.36254039177096875 0.3494687479801644
# ./data/train_experiments/expanded-transform/text-embedding-3-large/Frédéric_Chopin.pkl
# 136
# Correct percentage: 0.8161764705882353 0.8455882352941176
# Avg distance: 0.1413021678762401 0.0847801369998385
# ./data/train_experiments/expanded-transform/text-embedding-3-large/Hunting.pkl
# 60
# Correct percentage: 0.9333333333333333 0.95
# Avg distance: 0.21240638146021715 0.14661942049860954
# ./data/train_experiments/expanded-transform/text-embedding-3-large/Pharmaceutical_industry.pkl
# 54
# Correct percentage: 0.9814814814814815 0.9814814814814815
# Avg distance: 0.3205443350425749 0.25143070408591517
# ./data/train_experiments/expanded-transform/text-embedding-3-large/sciq-large.pkl
# 161
# Correct percentage: 0.9254658385093167 0.9316770186335404
# Avg distance: 0.2533478275959536 0.24642852180122587
# ./data/train_experiments/expanded-transform/text-embedding-3-large/sciq.pkl
# 300
# Correct percentage: 0.95 0.9466666666666667
# Avg distance: 0.2644349318866928 0.24026962691297135
# ./data/train_experiments/expanded-transform/text-embedding-ada-002/2008_Sichuan_earthquake.pkl
# 74
# Correct percentage: 0.7432432432432432 0.8108108108108109
# Avg distance: 0.11285158336741498 0.030221670060544402
# ./data/train_experiments/expanded-transform/text-embedding-ada-002/Antarctica.pkl
# 35
# Correct percentage: 0.9428571428571428 0.9142857142857143
# Avg distance: 0.2186633992141911 0.04776695626122611
# ./data/train_experiments/expanded-transform/text-embedding-ada-002/Beyoncé.pkl
# 117
# Correct percentage: 0.7777777777777778 0.7948717948717948
# Avg distance: 0.12219127289091165 0.026342830596826017
# ./data/train_experiments/expanded-transform/text-embedding-ada-002/dolly.pkl
# 266
# Correct percentage: 0.9624060150375939 0.981203007518797
# Avg distance: 0.2982332280143759 0.08949012438157447
# ./data/train_experiments/expanded-transform/text-embedding-ada-002/Frédéric_Chopin.pkl
# 136
# Correct percentage: 0.8014705882352942 0.8088235294117647
# Avg distance: 0.11287535208975896 0.02076562581693425
# ./data/train_experiments/expanded-transform/text-embedding-ada-002/Hunting.pkl
# 60
# Correct percentage: 0.8833333333333333 0.9166666666666666
# Avg distance: 0.18609569112304597 0.04149008095264435
# ./data/train_experiments/expanded-transform/text-embedding-ada-002/Pharmaceutical_industry.pkl
# 54
# Correct percentage: 0.9629629629629629 0.9074074074074074
# Avg distance: 0.26052438259918104 0.06392218890013518
# ./data/train_experiments/expanded-transform/text-embedding-ada-002/sciq-large.pkl
# 161
# Correct percentage: 0.9254658385093167 0.937888198757764
# Avg distance: 0.23852438690221828 0.06868452426069271
# ./data/train_experiments/expanded-transform/text-embedding-ada-002/sciq.pkl
# 300
# Correct percentage: 0.9466666666666667 0.95
# Avg distance: 0.24097170358834166 0.0693709554274877
# ./data/train_experiments/dimensionality-reduction/BAAI-bge-small-en-v1.5/2008_Sichuan_earthquake.pkl
# 74
# Correct percentage: 0.7837837837837838 0.8918918918918919
# Avg distance: 0.12226602471609777 0.06238058692700154
# ./data/train_experiments/dimensionality-reduction/BAAI-bge-small-en-v1.5/Antarctica.pkl
# 35
# Correct percentage: 0.8285714285714286 0.8857142857142857
# Avg distance: 0.21912985539862087 0.09441999367305211
# ./data/train_experiments/dimensionality-reduction/BAAI-bge-small-en-v1.5/Beyoncé.pkl
# 117
# Correct percentage: 0.7606837606837606 0.7948717948717948
# Avg distance: 0.09927654907935196 0.05112811158864926
# ./data/train_experiments/dimensionality-reduction/BAAI-bge-small-en-v1.5/dolly.pkl
# 266
# Correct percentage: 0.943609022556391 0.9699248120300752
# Avg distance: 0.2650598609133771 0.18065410157791653
# ./data/train_experiments/dimensionality-reduction/BAAI-bge-small-en-v1.5/Frédéric_Chopin.pkl
# 136
# Correct percentage: 0.75 0.7941176470588235
# Avg distance: 0.11208158152123146 0.05070231000290198
# ./data/train_experiments/dimensionality-reduction/BAAI-bge-small-en-v1.5/Hunting.pkl
# 60
# Correct percentage: 0.85 0.8833333333333333
# Avg distance: 0.19881908634367088 0.08855445484320322
# ./data/train_experiments/dimensionality-reduction/BAAI-bge-small-en-v1.5/Pharmaceutical_industry.pkl
# 54
# Correct percentage: 0.9259259259259259 0.9259259259259259
# Avg distance: 0.2596211646580034 0.1209840906990899
# ./data/train_experiments/dimensionality-reduction/BAAI-bge-small-en-v1.5/sciq-large.pkl
# 1500
# Correct percentage: 0.7453333333333333 0.8093333333333333
# Avg distance: 0.06924262368989488 0.06807315768798192
# ./data/train_experiments/dimensionality-reduction/BAAI-bge-small-en-v1.5/sciq.pkl
# 300
# Correct percentage: 0.9233333333333333 0.93
# Avg distance: 0.2131027663126588 0.1289899475375811
# ./data/train_experiments/dimensionality-reduction/Cohere-embed-english-v3.0/2008_Sichuan_earthquake.pkl
# 74
# Correct percentage: 0.9459459459459459 0.9054054054054054
# Avg distance: 0.16478243429918546 0.12105252533345609
# ./data/train_experiments/dimensionality-reduction/Cohere-embed-english-v3.0/Antarctica.pkl
# 35
# Correct percentage: 0.8857142857142857 0.9142857142857143
# Avg distance: 0.2507085587297167 0.16348790526390075
# ./data/train_experiments/dimensionality-reduction/Cohere-embed-english-v3.0/Beyoncé.pkl
# 117
# Correct percentage: 0.8717948717948718 0.9145299145299145
# Avg distance: 0.18165215096858323 0.10894423022738889
# ./data/train_experiments/dimensionality-reduction/Cohere-embed-english-v3.0/dolly.pkl
# 266
# Correct percentage: 0.9736842105263158 0.9736842105263158
# Avg distance: 0.32881442093311397 0.29939392483548116
# ./data/train_experiments/dimensionality-reduction/Cohere-embed-english-v3.0/Frédéric_Chopin.pkl
# 136
# Correct percentage: 0.8308823529411765 0.9117647058823529
# Avg distance: 0.15535815284751794 0.09806839793043978
# ./data/train_experiments/dimensionality-reduction/Cohere-embed-english-v3.0/Hunting.pkl
# 60
# Correct percentage: 0.95 0.95
# Avg distance: 0.2431314405364295 0.15200774172941844
# ./data/train_experiments/dimensionality-reduction/Cohere-embed-english-v3.0/Pharmaceutical_industry.pkl
# 54
# Correct percentage: 0.9444444444444444 1.0
# Avg distance: 0.2635215797840997 0.20984599849692098
# ./data/train_experiments/dimensionality-reduction/Cohere-embed-english-v3.0/sciq-large.pkl
# 1500
# Correct percentage: 0.8213333333333334 0.842
# Avg distance: 0.1082873521236082 0.10690912358959516
# ./data/train_experiments/dimensionality-reduction/Cohere-embed-english-v3.0/sciq.pkl
# 300
# Correct percentage: 0.9433333333333334 0.9466666666666667
# Avg distance: 0.23138980582356453 0.19893760671218236
# ./data/train_experiments/dimensionality-reduction/text-embedding-3-large/2008_Sichuan_earthquake.pkl
# 74
# Correct percentage: 0.8648648648648649 0.8918918918918919
# Avg distance: 0.12714491291223345 0.1009010062427134
# ./data/train_experiments/dimensionality-reduction/text-embedding-3-large/Antarctica.pkl
# 35
# Correct percentage: 0.8857142857142857 0.8571428571428571
# Avg distance: 0.23541883741106306 0.17459146891321456
# ./data/train_experiments/dimensionality-reduction/text-embedding-3-large/Beyoncé.pkl
# 117
# Correct percentage: 0.8376068376068376 0.8803418803418803
# Avg distance: 0.16024953545604506 0.10760460068018009
# ./data/train_experiments/dimensionality-reduction/text-embedding-3-large/dolly.pkl
# 266
# Correct percentage: 0.9774436090225563 0.9736842105263158
# Avg distance: 0.3552616417856145 0.3494687479801644
# ./data/train_experiments/dimensionality-reduction/text-embedding-3-large/Frédéric_Chopin.pkl
# 136
# Correct percentage: 0.8161764705882353 0.8455882352941176
# Avg distance: 0.13742066345259765 0.0847801369998385
# ./data/train_experiments/dimensionality-reduction/text-embedding-3-large/Hunting.pkl
# 60
# Correct percentage: 0.9166666666666666 0.95
# Avg distance: 0.21170774875208737 0.14661942049860954
# ./data/train_experiments/dimensionality-reduction/text-embedding-3-large/Pharmaceutical_industry.pkl
# 54
# Correct percentage: 0.9814814814814815 0.9814814814814815
# Avg distance: 0.3279624924374123 0.25143070408591517
# ./data/train_experiments/dimensionality-reduction/text-embedding-3-large/sciq-large.pkl
# 161
# Correct percentage: 0.9254658385093167 0.9316770186335404
# Avg distance: 0.25573974014809414 0.24642852180122587
# ./data/train_experiments/dimensionality-reduction/text-embedding-3-large/sciq.pkl
# 300
# Correct percentage: 0.9566666666666667 0.9466666666666667
# Avg distance: 0.2671987171533207 0.24026962691297135
# ./data/train_experiments/dimensionality-reduction/text-embedding-ada-002/2008_Sichuan_earthquake.pkl
# 74
# Correct percentage: 0.7837837837837838 0.8108108108108109
# Avg distance: 0.10722252638456789 0.030221670060544402
# ./data/train_experiments/dimensionality-reduction/text-embedding-ada-002/Antarctica.pkl
# 35
# Correct percentage: 0.8571428571428571 0.9142857142857143
# Avg distance: 0.2074033691414765 0.04776695626122611
# ./data/train_experiments/dimensionality-reduction/text-embedding-ada-002/Beyoncé.pkl
# 117
# Correct percentage: 0.7606837606837606 0.7948717948717948
# Avg distance: 0.11212425754190637 0.026342830596826017
# ./data/train_experiments/dimensionality-reduction/text-embedding-ada-002/dolly.pkl
# 266
# Correct percentage: 0.9661654135338346 0.981203007518797
# Avg distance: 0.2914944511831255 0.08949012438157447
# ./data/train_experiments/dimensionality-reduction/text-embedding-ada-002/Frédéric_Chopin.pkl
# 136
# Correct percentage: 0.7647058823529411 0.8088235294117647
# Avg distance: 0.09418104309588671 0.02076562581693425
# ./data/train_experiments/dimensionality-reduction/text-embedding-ada-002/Hunting.pkl
# 60
# Correct percentage: 0.8 0.9166666666666666
# Avg distance: 0.18165149182702103 0.04149008095264435
# ./data/train_experiments/dimensionality-reduction/text-embedding-ada-002/Pharmaceutical_industry.pkl
# 54
# Correct percentage: 0.9259259259259259 0.9074074074074074
# Avg distance: 0.24842786218074184 0.06392218890013518
# ./data/train_experiments/dimensionality-reduction/text-embedding-ada-002/sciq-large.pkl
# 161
# Correct percentage: 0.9130434782608695 0.937888198757764
# Avg distance: 0.23039015947106462 0.06868452426069271
# ./data/train_experiments/dimensionality-reduction/text-embedding-ada-002/sciq.pkl
# 300
# Correct percentage: 0.94 0.95
# Avg distance: 0.22949388821919758 0.0693709554274877
# ./data/train_experiments/single-layer-squared-0.2-dropout-long-train-low-margin/BAAI-bge-small-en-v1.5/2008_Sichuan_earthquake.pkl
# 74
# Correct percentage: 0
# ./data/train_experiments/single-layer-squared-no-dropout-long-train-low-margin/text-embedding-ada-002/sciq-large.pkl
# 161
# Correct percentage: 0.937888198757764 0.937888198757764
# Avg distance: 0.09183078782158609 0.06868452426069271
# ./data/train_experiments/single-layer-squared-no-dropout-long-train-low-margin/text-embedding-ada-002/sciq.pkl
# 300
# Correct percentage: 0.9466666666666667 0.95
# Avg distance: 0.2410077304765582 0.0693709554274877
# -0.009910343792939773 0.031437348469109054
# -0.006354419326603085 0.017920904094729337
# 0.08133625588648753 0.051747205552485534

# %%
import pandas as pd
df = pd.DataFrame.from_records(result_df_entries)

# %%
df
# Out:
#                                        experiment_name  \
# 0                                   expanded-transform
# 1                                   expanded-transform
# 2                                   expanded-transform
# 3                                   expanded-transform
# 4                                   expanded-transform
# ..                                                 ...
# 139  single-layer-squared-no-dropout-long-train-low...
# 140  single-layer-squared-no-dropout-long-train-low...
# 141  single-layer-squared-no-dropout-long-train-low...
# 142  single-layer-squared-no-dropout-long-train-low...
# 143  single-layer-squared-no-dropout-long-train-low...
#
#                  model_name                  dataset  top_1_accuracy_trans  \
# 0    BAAI-bge-small-en-v1.5  2008_Sichuan_earthquake              0.891892
# 1    BAAI-bge-small-en-v1.5               Antarctica              0.885714
# 2    BAAI-bge-small-en-v1.5                  Beyoncé              0.863248
# 3    BAAI-bge-small-en-v1.5                    dolly              0.977444
# 4    BAAI-bge-small-en-v1.5          Frédéric_Chopin              0.889706
# ..                      ...                      ...                   ...
# 139  text-embedding-ada-002          Frédéric_Chopin              0.816176
# 140  text-embedding-ada-002                  Hunting              0.883333
# 141  text-embedding-ada-002  Pharmaceutical_industry              0.962963
# 142  text-embedding-ada-002               sciq-large              0.937888
# 143  text-embedding-ada-002                     sciq              0.946667
#
#      top_1_accuracy_orig  top_3_accuracy_trans  top_3_accuracy_orig  \
# 0               0.891892              0.972973             0.972973
# 1               0.885714              1.000000             1.000000
# 2               0.794872              0.982906             0.974359
# 3               0.969925              0.992481             0.992481
# 4               0.794118              0.963235             0.963235
# ..                   ...                   ...                  ...
# 139             0.808824              0.970588             0.970588
# 140             0.916667              0.983333             0.983333
# 141             0.907407              1.000000             1.000000
# 142             0.937888              0.987578             0.981366
# 143             0.950000              0.983333             0.983333
#
#      top_5_accuracy_trans  top_5_accuracy_orig  mrr_trans  mrr_orig  \
# 0                0.986486             1.000000   0.932995  0.936261
# 1                1.000000             1.000000   0.942857  0.942857
# 2                1.000000             1.000000   0.922650  0.887322
# 3                0.996241             0.996241   0.988252  0.978822
# 4                0.977941             0.970588   0.929298  0.879926
# ..                    ...                  ...        ...       ...
# 139              0.992647             0.992647   0.887561  0.884375
# 140              1.000000             1.000000   0.934722  0.954167
# 141              1.000000             1.000000   0.975309  0.947531
# 142              0.987578             0.987578   0.958823  0.958293
# 143              0.986667             0.986667   0.965636  0.966647
#
#      distance_to_first_wrong_trans  distance_to_first_wrong_orig
# 0                         0.137607                      0.062381
# 1                         0.217292                      0.094420
# 2                         0.142170                      0.051128
# 3                         0.306446                      0.180654
# 4                         0.151692                      0.050702
# ..                             ...                           ...
# 139                       0.115738                      0.020766
# 140                       0.186377                      0.041490
# 141                       0.262266                      0.063922
# 142                       0.091831                      0.068685
# 143                       0.241008                      0.069371
#
# [144 rows x 13 columns]

# %%
df['distance_delta'] = df['distance_to_first_wrong_trans'] - df['distance_to_first_wrong_orig']

# %%
df.groupby(["experiment_name", "model_name"])[["avg_", "distance_to_first_wrong_orig", "distance_delta"]].std().round(3)
# Out:
#                                                                               distance_to_first_wrong_trans  \
# experiment_name                                    model_name
# dimensionality-reduction                           BAAI-bge-small-en-v1.5                             0.073
#                                                    Cohere-embed-english-v3.0                          0.067
#                                                    text-embedding-3-large                             0.080
#                                                    text-embedding-ada-002                             0.070
# expanded-transform                                 BAAI-bge-small-en-v1.5                             0.065
#                                                    Cohere-embed-english-v3.0                          0.068
#                                                    text-embedding-3-large                             0.080
#                                                    text-embedding-ada-002                             0.069
# single-layer-squared-0.2-dropout-long-train-low... BAAI-bge-small-en-v1.5                             0.076
#                                                    Cohere-embed-english-v3.0                          0.062
#                                                    text-embedding-3-large                             0.074
#                                                    text-embedding-ada-002                             0.083
# single-layer-squared-no-dropout-long-train-low-... BAAI-bge-small-en-v1.5                             0.075
#                                                    Cohere-embed-english-v3.0                          0.059
#                                                    text-embedding-3-large                             0.072
#                                                    text-embedding-ada-002                             0.076
#
#                                                                               distance_to_first_wrong_orig  \
# experiment_name                                    model_name
# dimensionality-reduction                           BAAI-bge-small-en-v1.5                            0.043
#                                                    Cohere-embed-english-v3.0                         0.065
#                                                    text-embedding-3-large                            0.089
#                                                    text-embedding-ada-002                            0.023
# expanded-transform                                 BAAI-bge-small-en-v1.5                            0.043
#                                                    Cohere-embed-english-v3.0                         0.065
#                                                    text-embedding-3-large                            0.089
#                                                    text-embedding-ada-002                            0.023
# single-layer-squared-0.2-dropout-long-train-low... BAAI-bge-small-en-v1.5                            0.043
#                                                    Cohere-embed-english-v3.0                         0.065
#                                                    text-embedding-3-large                            0.089
#                                                    text-embedding-ada-002                            0.023
# single-layer-squared-no-dropout-long-train-low-... BAAI-bge-small-en-v1.5                            0.043
#                                                    Cohere-embed-english-v3.0                         0.065
#                                                    text-embedding-3-large                            0.089
#                                                    text-embedding-ada-002                            0.023
#
#                                                                               distance_delta
# experiment_name                                    model_name
# dimensionality-reduction                           BAAI-bge-small-en-v1.5              0.042
#                                                    Cohere-embed-english-v3.0           0.029
#                                                    text-embedding-3-large              0.025
#                                                    text-embedding-ada-002              0.048
# expanded-transform                                 BAAI-bge-small-en-v1.5              0.028
#                                                    Cohere-embed-english-v3.0           0.026
#                                                    text-embedding-3-large              0.028
#                                                    text-embedding-ada-002              0.047
# single-layer-squared-0.2-dropout-long-train-low... BAAI-bge-small-en-v1.5              0.044
#                                                    Cohere-embed-english-v3.0           0.023
#                                                    text-embedding-3-large              0.026
#                                                    text-embedding-ada-002              0.069
# single-layer-squared-no-dropout-long-train-low-... BAAI-bge-small-en-v1.5              0.044
#                                                    Cohere-embed-english-v3.0           0.024
#                                                    text-embedding-3-large              0.026
#                                                    text-embedding-ada-002              0.062

# %%
df.agg(
    top_1_mean=('top_n_accuracy_trans', np.mean),
    top_1_std=('top_n_accuracy_trans', np.std),
    top_1_mean_orig=('top_n_accuracy_orig', np.mean),
    top_1_std_orig=('top_n_accuracy_orig', np.std)
)
# Out:
# /tmp/ipykernel_423/2462951148.py:1: FutureWarning: The provided callable <function mean at 0x7f0af018f600> is currently using Series.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.agg(
# /tmp/ipykernel_423/2462951148.py:1: FutureWarning: The provided callable <function std at 0x7f0af018f740> is currently using Series.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   df.agg(
#                  top_n_accuracy_trans  top_n_accuracy_orig
# top_1_mean                   0.983707                  NaN
# top_1_std                    0.019817                  NaN
# top_1_mean_orig                   NaN             0.984277
# top_1_std_orig                    NaN             0.017396

# %%
squad_df = df[(df['dataset'] != "dolly") & (df['dataset'] != "sciq") & (df['dataset'] != "sciq-large")]
squad_df['first_wrong_delta'] = squad_df['distance_to_first_wrong_trans'] - squad_df['distance_to_first_wrong_orig']
squad_df.groupby("model_name").agg(
    mean=('first_wrong_delta', np.mean),
    std=('first_wrong_delta', np.std)
)
# Out:
# /tmp/ipykernel_423/3283763391.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   squad_df['first_wrong_delta'] = squad_df['distance_to_first_wrong_trans'] - squad_df['distance_to_first_wrong_orig']
# /tmp/ipykernel_423/3283763391.py:3: FutureWarning: The provided callable <function mean at 0x7f0af018f600> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   squad_df.groupby("model_name").agg(
# /tmp/ipykernel_423/3283763391.py:3: FutureWarning: The provided callable <function std at 0x7f0af018f740> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   squad_df.groupby("model_name").agg(
#                                mean       std
# model_name
# BAAI-bge-small-en-v1.5     0.103989  0.027972
# Cohere-embed-english-v3.0  0.071806  0.016947
# text-embedding-3-large     0.055663  0.014745
# text-embedding-ada-002     0.118148  0.046806

# %%
sciq_df = df[df['dataset'] == "sciq-large"]
sciq_df['first_wrong_delta'] = sciq_df['distance_to_first_wrong_trans'] - sciq_df['distance_to_first_wrong_orig']
sciq_df.groupby("model_name").agg(
    mean=('first_wrong_delta', np.mean),
    std=('first_wrong_delta', np.std),
    mean_fw_trans=('distance_to_first_wrong_trans', np.mean),
    mean_fw_orig=('distance_to_first_wrong_orig', np.mean),
    mean_class_trans=('top_n_accuracy_trans', np.mean),
    mean_class_orig=('top_n_accuracy_orig', np.mean)
)
# Out:
# /tmp/ipykernel_423/4182437090.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sciq_df['first_wrong_delta'] = sciq_df['distance_to_first_wrong_trans'] - sciq_df['distance_to_first_wrong_orig']
# /tmp/ipykernel_423/4182437090.py:3: FutureWarning: The provided callable <function mean at 0x7f0af018f600> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   sciq_df.groupby("model_name").agg(
# /tmp/ipykernel_423/4182437090.py:3: FutureWarning: The provided callable <function std at 0x7f0af018f740> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   sciq_df.groupby("model_name").agg(
# /tmp/ipykernel_423/4182437090.py:3: FutureWarning: The provided callable <function mean at 0x7f0af018f600> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   sciq_df.groupby("model_name").agg(
#                                mean  std  mean_fw_trans  mean_fw_orig  \
# model_name
# BAAI-bge-small-en-v1.5     0.071100  NaN       0.184905      0.113805
# Cohere-embed-english-v3.0  0.033046  NaN       0.209763      0.176718
# text-embedding-3-large     0.024151  NaN       0.243961      0.219810
# text-embedding-ada-002     0.149558  NaN       0.211682      0.062124
#
#                            mean_class_trans  mean_class_orig
# model_name
# BAAI-bge-small-en-v1.5             0.893333         0.903333
# Cohere-embed-english-v3.0          0.913333         0.926667
# text-embedding-3-large             0.953333         0.956667
# text-embedding-ada-002             0.936667         0.936667
