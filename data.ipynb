# %% [markdown]
# ## Load data and chose categories

# %%
import json
import torch
import pickle

# %%
with open('data/squad2-train.json', 'r') as file: #place squad2-train.json in data folder. Download from https://rajpurkar.github.io/SQuAD-explorer/
    train_data = json.load(file)

# %%
categories = []

# %%
for i, category in enumerate(train_data['data']):
    title = category['title']
    question_count = 0
    context_count = len(category['paragraphs'])
    for paragraph in category['paragraphs']:
        question_count += len(paragraph['qas'])
    categories.append((i, title, question_count, context_count))

# %%
sorted(categories, key=lambda x: x[2], reverse=True)
# Out:
# [(171, 'Queen_Victoria', 883, 42),
#  (7, 'New_York_City', 817, 148),
#  (12, 'American_Idol', 790, 127),
#  (0, 'Beyoncé', 753, 66),
#  (1, 'Frédéric_Chopin', 697, 82),
#  (11, 'Buddhism', 610, 149),
#  (168, 'Pharmaceutical_industry', 586, 44),
#  (250, 'New_Haven,_Connecticut', 582, 66),
#  (380, 'Premier_League', 551, 40),
#  (438, 'Hunting', 531, 36),
#  (152, 'Antarctica', 525, 44),
#  (6, '2008_Sichuan_earthquake', 521, 77),
#  (107, 'Houston', 521, 48),
#  (351, 'Steven_Spielberg', 512, 49),
#  (291, 'PlayStation_3', 508, 44),
#  (390, 'Alfred_North_Whitehead', 502, 47),
#  (14, '2008_Summer_Olympics_torch_relay', 500, 74),
#  (356, 'Charleston,_South_Carolina', 490, 48),
#  (144, 'Macintosh', 487, 49),
#  (349, 'Muammar_Gaddafi', 485, 76),
#  (166, 'Multiracial_American', 481, 44),
#  (383, 'San_Diego', 475, 49),
#  (5, 'Spectre_(2015_film)', 462, 43),
#  (379, 'Greeks', 458, 44),
#  (91, 'Middle_Ages', 452, 93),
#  (217, 'Yale_University', 452, 46),
#  (365, 'Modern_history', 448, 88),
#  (306, 'Mandolin', 446, 43),
#  (172, 'Freemasonry', 444, 37),
#  (392, 'Windows_8', 442, 48),
#  (140, 'Federal_Bureau_of_Investigation', 441, 45),
#  (174, 'Hellenistic_period', 440, 94),
#  (236, 'Avicenna', 440, 35),
#  (248, 'Affirmative_action_in_the_United_States', 440, 48),
#  (73, 'Slavs', 437, 49),
#  (194, 'Napoleon', 436, 89),
#  (335, 'Miami', 436, 45),
#  (238, 'Bermuda', 434, 47),
#  (285, 'Gamal_Abdel_Nasser', 433, 95),
#  (421, 'Jehovah%27s_Witnesses', 433, 46),
#  (157, 'Elizabeth_II', 431, 45),
#  (422, 'Dwight_D._Eisenhower', 430, 90),
#  (409, 'Red', 429, 48),
#  (10, 'Kanye_West', 428, 79),
#  (281, 'Northwestern_University', 427, 44),
#  (425, 'Portugal', 427, 98),
#  (74, 'Southampton', 426, 95),
#  (304, 'Alaska', 426, 48),
#  (159, 'Dell', 424, 45),
#  (160, 'Capital_punishment_in_the_United_States', 422, 47),
#  (101, 'House_music', 420, 44),
#  (131, 'Military_history_of_the_United_States', 414, 42),
#  (357, 'The_Blitz', 414, 92),
#  (267, 'Dominican_Order', 413, 44),
#  (70, 'Westminster_Abbey', 411, 46),
#  (186, 'Greece', 406, 95),
#  (413, 'Religion_in_ancient_Rome', 405, 81),
#  (262, 'Gramophone_record', 404, 85),
#  (269, 'Cork_(city)', 404, 30),
#  (287, 'Time', 402, 29),
#  (415, 'Separation_of_church_and_state_in_the_United_States', 402, 41),
#  (353, 'Neptune', 399, 36),
#  (23, 'Canadian_Armed_Forces', 396, 46),
#  (361, 'Quran', 396, 43),
#  (88, 'High-definition_television', 394, 46),
#  (180, 'Incandescent_light_bulb', 393, 42),
#  (13, 'Dog', 392, 75),
#  (218, 'Late_Middle_Ages', 392, 40),
#  (381, 'Roman_Republic', 392, 82),
#  (305, 'Karl_Popper', 391, 43),
#  (193, 'Mexico_City', 390, 87),
#  (382, 'Pacific_War', 390, 71),
#  (424, 'Financial_crisis_of_2007%E2%80%9308', 390, 79),
#  (284, 'History_of_India', 389, 78),
#  (309, 'Paris', 389, 94),
#  (179, 'Buckingham_Palace', 388, 28),
#  (153, 'Eritrea', 386, 40),
#  (197, 'Brigham_Young_University', 386, 37),
#  (154, 'Uranium', 385, 41),
#  (404, 'Light-emitting_diode', 385, 43),
#  (162, 'Nintendo_Entertainment_System', 383, 44),
#  (225, 'Edmund_Burke', 383, 40),
#  (198, 'Department_store', 378, 40),
#  (433, 'Anthropology', 378, 45),
#  (163, 'Athanasius_of_Alexandria', 377, 36),
#  (121, 'Emotion', 375, 44),
#  (220, 'Gothic_architecture', 375, 40),
#  (4, 'The_Legend_of_Zelda:_Twilight_Princess', 374, 32),
#  (268, 'Eton_College', 374, 43),
#  (68, 'Dialect', 373, 44),
#  (59, 'Paper', 371, 32),
#  (185, 'Copyright_infringement', 371, 39),
#  (241, 'Molotov%E2%80%93Ribbentrop_Pact', 371, 44),
#  (375, 'Tucson,_Arizona', 370, 52),
#  (416, 'Protestantism', 369, 75),
#  (57, 'Universal_Studios', 368, 42),
#  (33, 'Plymouth', 367, 81),
#  (86, 'Zhejiang', 367, 38),
#  (141, 'Mary_(mother_of_Jesus)', 366, 41),
#  (235, 'Literature', 366, 23),
#  (113, 'Computer_security', 365, 25),
#  (242, 'Capacitor', 364, 37),
#  (228, 'Electric_motor', 363, 42),
#  (275, 'London', 359, 77),
#  (401, 'Namibia', 359, 38),
#  (386, 'British_Isles', 357, 34),
#  (44, 'Pub', 356, 90),
#  (301, 'War_on_Terror', 356, 31),
#  (229, 'Switzerland', 353, 77),
#  (170, 'Asphalt', 352, 36),
#  (345, 'Post-punk', 352, 22),
#  (56, 'Boston', 350, 79),
#  (208, 'Madonna_(entertainer)', 349, 76),
#  (184, 'Korean_War', 348, 75),
#  (161, 'Age_of_Enlightenment', 347, 83),
#  (80, 'Alps', 346, 87),
#  (42, 'Russian_Soviet_Federative_Socialist_Republic', 345, 34),
#  (28, 'Architecture', 344, 38),
#  (321, 'Zinc', 344, 38),
#  (307, 'Insect', 343, 60),
#  (371, 'Washington_University_in_St._Louis', 341, 35),
#  (55, 'Catalan_language', 340, 80),
#  (65, 'University_of_Kansas', 340, 36),
#  (145, 'Anti-aircraft_warfare', 340, 70),
#  (329, 'Ottoman_Empire', 340, 69),
#  (116, 'Beer', 339, 34),
#  (210, 'Myanmar', 339, 73),
#  (428, 'Police', 339, 36),
#  (17, 'Republic_of_the_Congo', 338, 39),
#  (298, 'Federalism', 338, 38),
#  (124, 'Aircraft_carrier', 337, 34),
#  (292, 'Royal_assent', 335, 38),
#  (181, 'Arsenal_F.C.', 334, 34),
#  (209, 'Law_of_the_United_States', 332, 27),
#  (216, 'Somerset', 332, 37),
#  (231, 'Raleigh,_North_Carolina', 332, 34),
#  (272, 'Sichuan', 332, 26),
#  (274, 'Detroit', 330, 79),
#  (89, 'Wood', 328, 70),
#  (3, 'IPod', 327, 60),
#  (43, 'Alexander_Graham_Bell', 325, 74),
#  (76, 'Josip_Broz_Tito', 325, 67),
#  (308, 'Race_(human_categorization)', 325, 65),
#  (378, 'Printed_circuit_board', 325, 35),
#  (195, 'Germans', 324, 32),
#  (407, 'Qing_dynasty', 324, 81),
#  (414, 'YouTube', 324, 34),
#  (46, 'Comics', 323, 37),
#  (360, 'Han_dynasty', 323, 65),
#  (24, 'Cardinal_(Catholicism)', 322, 45),
#  (279, 'Tibet', 322, 39),
#  (282, 'Strasbourg', 321, 34),
#  (151, 'Adolescence', 320, 78),
#  (118, 'United_States_dollar', 319, 32),
#  (169, 'Umayyad_Caliphate', 318, 35),
#  (259, 'Crucifixion_of_Jesus', 318, 32),
#  (202, 'Presbyterianism', 317, 38),
#  (396, 'Kievan_Rus%27', 317, 39),
#  (249, 'FA_Cup', 316, 32),
#  (354, 'Railway_electrification_system', 316, 34),
#  (299, 'Annelid', 314, 35),
#  (40, 'Hunter-gatherer', 313, 34),
#  (47, 'Saint_Helena', 313, 82),
#  (72, 'Classical_music', 313, 68),
#  (334, 'Madrasa', 313, 35),
#  (66, 'Nanjing', 312, 66),
#  (411, 'Mosaic', 311, 64),
#  (412, 'University', 311, 27),
#  (142, 'Melbourne', 310, 64),
#  (177, 'Poultry', 310, 31),
#  (200, 'Florida', 309, 35),
#  (243, 'History_of_science', 309, 67),
#  (211, 'Jews', 308, 36),
#  (189, 'East_India_Company', 307, 31),
#  (90, 'Somalis', 306, 71),
#  (103, 'Chihuahua_(state)', 306, 66),
#  (52, 'BeiDou_Navigation_Satellite_System', 305, 34),
#  (108, 'Copper', 304, 31),
#  (348, 'Richard_Feynman', 304, 32),
#  (135, 'Biodiversity', 302, 32),
#  (367, 'Antenna_(radio)', 302, 74),
#  (431, 'Tajikistan', 302, 34),
#  (347, 'Seven_Years%27_War', 301, 61),
#  (212, 'Cotton', 300, 30),
#  (258, 'Dissolution_of_the_Soviet_Union', 299, 67),
#  (399, 'Tuvalu', 299, 61),
#  (247, 'Tuberculosis', 298, 31),
#  (303, 'Estonia', 298, 72),
#  (391, 'Antibiotics', 298, 26),
#  (173, 'Israel', 297, 99),
#  (255, 'North_Carolina', 297, 61),
#  (149, 'United_States_Army', 296, 34),
#  (339, 'Guam', 295, 36),
#  (221, 'Cubism', 294, 39),
#  (206, 'British_Empire', 293, 60),
#  (300, 'God', 293, 24),
#  (366, '51st_state', 293, 32),
#  (158, 'Sexual_orientation', 292, 53),
#  (165, 'Memory', 292, 32),
#  (224, 'Norfolk_Island', 292, 30),
#  (373, 'Pain', 292, 33),
#  (2, 'Sino-Tibetan_relations_during_the_Ming_dynasty', 291, 72),
#  (436, 'Richmond,_Virginia', 291, 61),
#  (273, 'Unicode', 290, 33),
#  (402, 'Russian_language', 290, 31),
#  (437, 'Infection', 290, 30),
#  (100, 'MP3', 289, 62),
#  (318, 'Renewable_energy_commercialization', 289, 40),
#  (150, 'Franco-Prussian_War', 287, 58),
#  (233, 'Crimean_War', 287, 62),
#  (418, 'Economy_of_Greece', 287, 29),
#  (94, 'Black_people', 286, 61),
#  (261, 'Textual_criticism', 286, 32),
#  (327, 'Energy', 284, 33),
#  (429, 'Genocide', 284, 26),
#  (204, 'Predation', 282, 26),
#  (359, 'Vacuum', 282, 31),
#  (385, 'Iran', 282, 60),
#  (75, 'Treaty', 281, 57),
#  (302, 'Labour_Party_(UK)', 280, 41),
#  (81, 'Gene', 279, 56),
#  (342, 'Czech_language', 279, 28),
#  (266, 'A_cappella', 278, 23),
#  (341, 'Idealism', 278, 29),
#  (394, 'Translation', 277, 29),
#  (77, 'Marshall_Islands', 276, 51),
#  (78, 'Szlachta', 276, 63),
#  (439, 'Kathmandu', 276, 58),
#  (146, 'Sanskrit', 275, 22),
#  (232, 'Nutrition', 275, 56),
#  (408, 'Indigenous_peoples_of_the_Americas', 275, 56),
#  (358, 'Endangered_Species_Act', 274, 31),
#  (398, 'Sumer', 274, 32),
#  (61, 'Daylight_saving_time', 273, 63),
#  (374, 'Database', 272, 32),
#  (227, 'Pope_Paul_VI', 271, 55),
#  (283, 'Oklahoma', 271, 55),
#  (315, 'States_of_Germany', 270, 24),
#  (58, 'Estonian_language', 269, 33),
#  (201, 'Queen_(band)', 269, 59),
#  (432, 'University_of_Notre_Dame', 269, 55),
#  (343, 'Education', 267, 35),
#  (423, 'The_Bronx', 267, 57),
#  (246, 'Comcast', 266, 27),
#  (277, 'Sahara', 265, 25),
#  (317, 'Planck_constant', 265, 24),
#  (203, 'Thuringia', 264, 29),
#  (67, 'Arena_Football_League', 262, 55),
#  (355, 'Spanish_language_in_the_United_States', 262, 23),
#  (257, 'On_the_Origin_of_Species', 261, 59),
#  (419, 'Party_leaders_of_the_United_States_House_of_Representatives', 261, 31),
#  (164, 'Seattle', 260, 52),
#  (219, 'Ann_Arbor,_Michigan', 260, 35),
#  (326, 'IBM', 260, 26),
#  (369, 'Hyderabad', 260, 53),
#  (387, 'Association_football', 260, 28),
#  (48, 'Aspirated_consonant', 259, 34),
#  (252, 'Carnival', 259, 52),
#  (293, 'Group_(mathematics)', 259, 30),
#  (192, 'Film_speed', 258, 26),
#  (311, 'United_States_presidential_election,_2004', 257, 26),
#  (130, 'Xbox_360', 256, 26),
#  (426, 'Humanism', 256, 30),
#  (119, 'Imperial_College_London', 255, 25),
#  (239, 'Nigeria', 254, 55),
#  (96, 'New_Delhi', 253, 52),
#  (288, 'European_Central_Bank', 253, 28),
#  (143, 'John,_King_of_England', 250, 76),
#  (147, 'Valencia', 250, 51),
#  (178, 'Dutch_language', 250, 51),
#  (435, 'Punjab,_Pakistan', 250, 26),
#  (9, 'Solar_energy', 249, 52),
#  (132, 'Hard_rock', 249, 25),
#  (139, 'FC_Barcelona', 249, 50),
#  (316, 'Glass', 249, 26),
#  (427, 'Geological_history_of_Earth', 249, 26),
#  (226, 'Samoa', 248, 25),
#  (176, 'Montevideo', 247, 70),
#  (205, 'Marvel_Comics', 247, 25),
#  (350, 'Cyprus', 247, 59),
#  (410, 'Egypt', 247, 64),
#  (63, 'National_Archives_and_Records_Administration', 246, 28),
#  (214, 'The_Sun_(United_Kingdom)', 246, 49),
#  (337, 'John_Kerry', 246, 52),
#  (97, 'Bird_migration', 245, 56),
#  (187, 'Royal_Dutch_Shell', 245, 25),
#  (191, 'Professional_wrestling', 245, 61),
#  (222, 'Political_philosophy', 245, 21),
#  (264, 'Hindu_philosophy', 245, 25),
#  (265, 'Political_party', 245, 27),
#  (82, 'Guinea-Bissau', 243, 50),
#  (420, 'Armenians', 243, 25),
#  (38, 'Sony_Music_Entertainment', 242, 35),
#  (215, 'Pesticide', 242, 26),
#  (340, 'Empiricism', 242, 25),
#  (376, 'Armenia', 241, 57),
#  (384, 'Muslim_world', 241, 27),
#  (403, 'United_States_Air_Force', 241, 57),
#  (114, 'Orthodox_Judaism', 240, 25),
#  (62, 'Royal_Institute_of_British_Architects', 239, 27),
#  (190, 'Hokkien', 239, 21),
#  (336, 'Philadelphia', 239, 59),
#  (338, 'Rajasthan', 239, 24),
#  (352, 'Elevator', 239, 52),
#  (289, 'St._John%27s,_Newfoundland_and_Labrador', 238, 31),
#  (136, 'ASCII', 237, 26),
#  (87, 'Ministry_of_Defence_(United_Kingdom)', 236, 25),
#  (254, 'Child_labour', 236, 61),
#  (295, 'Asthma', 236, 25),
#  (346, 'Canadian_football', 236, 21),
#  (430, 'Saint_Barth%C3%A9lemy', 236, 24),
#  (54, 'Communications_in_Somalia', 235, 25),
#  (234, 'Nonprofit_organization', 235, 24),
#  (271, 'USB', 235, 66),
#  (313, 'Samurai', 235, 50),
#  (286, 'Pope_John_XXIII', 234, 25),
#  (207, 'Botany', 233, 51),
#  (397, 'Super_Nintendo_Entertainment_System', 233, 24),
#  (344, 'Tennessee', 232, 50),
#  (368, 'Flowering_plant', 232, 24),
#  (393, 'Swaziland', 231, 27),
#  (27, 'Separation_of_powers_under_the_United_States_Constitution', 230, 29),
#  (98, 'Atlantic_City,_New_Jersey', 230, 47),
#  (122, 'Everton_F.C.', 230, 24),
#  (294, 'Central_African_Republic', 230, 23),
#  (363, 'Compact_disc', 230, 25),
#  (406, 'Bird', 230, 62),
#  (85, 'Near_East', 229, 59),
#  (320, 'Green', 229, 27),
#  (8, 'To_Kill_a_Mockingbird', 228, 62),
#  (251, 'Alsace', 228, 27),
#  (325, 'Appalachian_Mountains', 228, 35),
#  (332, 'Friedrich_Hayek', 227, 50),
#  (110, 'Himachal_Pradesh', 226, 23),
#  (389, 'Liberia', 226, 23),
#  (93, 'Computer', 224, 80),
#  (417, 'Bras%C3%ADlia', 223, 23),
#  (84, 'Brain', 222, 64),
#  (32, 'Arnold_Schwarzenegger', 221, 86),
#  (138, 'Gymnastics', 220, 23),
#  (370, 'Santa_Monica,_California', 220, 22),
#  (395, 'Airport', 220, 25),
#  (31, 'BBC_Television', 219, 31),
#  (37, 'Christian', 218, 28),
#  (60, 'Adult_contemporary_music', 216, 53),
#  (263, 'Turner_Classic_Movies', 216, 23),
#  (290, 'John_von_Neumann', 216, 63),
#  (312, 'Liberal_Party_of_Australia', 216, 26),
#  (314, 'Software_testing', 216, 29),
#  (364, 'Transistor', 216, 23),
#  (377, 'Bacteria', 216, 51),
#  (79, 'Virgil', 215, 23),
#  (196, 'Southeast_Asia', 215, 26),
#  (30, 'Southern_Europe', 214, 25),
#  (213, 'Data_compression', 214, 26),
#  (83, 'List_of_numbered_streets_in_Manhattan', 213, 50),
#  (230, 'Mali', 212, 22),
#  (328, 'East_Prussia', 211, 27),
#  (95, 'The_Times', 210, 53),
#  (129, 'Gregorian_calendar', 210, 23),
#  (183, 'Chicago_Cubs', 210, 63),
#  (240, 'Utrecht', 210, 27),
#  (278, 'Rule_of_law', 209, 24),
#  (20, 'Wayback_Machine', 208, 26),
#  (188, 'Mammal', 208, 24),
#  (128, 'Videoconferencing', 206, 21),
#  (256, 'Heian_period', 205, 24),
#  (330, 'Philosophy_of_space_and_time', 205, 24),
#  (331, 'Neolithic', 205, 23),
#  (34, 'Heresy', 204, 29),
#  (92, 'Phonology', 204, 23),
#  (36, 'Materialism', 203, 33),
#  (182, 'Clothing', 203, 21),
#  (253, 'Baptists', 203, 23),
#  (156, 'Circadian_rhythm', 202, 22),
#  (15, 'Genome', 201, 25),
#  (21, 'Dutch_Republic', 201, 21),
#  (319, 'Palermo', 201, 24),
#  (244, 'Digimon', 200, 21),
#  (245, 'Glacier', 199, 23),
#  (260, 'Supreme_court', 199, 23),
#  (16, 'Comprehensive_school', 198, 25),
#  (223, 'Alloy', 198, 22),
#  (280, 'Exhibition_game', 198, 21),
#  (297, 'George_VI', 198, 23),
#  (120, 'Hanover', 197, 21),
#  (400, 'Immaculate_Conception', 197, 22),
#  (18, 'Prime_minister', 196, 36),
#  (41, 'United_Nations_Population_Fund', 196, 22),
#  (53, 'Canon_law', 195, 22),
#  (126, 'Lancashire', 195, 20),
#  (322, 'Neoclassical_architecture', 193, 22),
#  (51, 'Web_browser', 192, 24),
#  (167, 'Ashkenazi_Jews', 190, 50),
#  (324, 'CBC_Television', 190, 25),
#  (362, 'Geography_of_the_United_States', 190, 21),
#  (199, 'Intellectual_property', 188, 21),
#  (388, 'Georgian_architecture', 188, 21),
#  (405, 'Great_power', 188, 21),
#  (64, 'Tristan_da_Cunha', 187, 29),
#  (123, 'Old_English', 187, 23),
#  (175, 'Bill_%26_Melinda_Gates_Foundation', 185, 21),
#  (276, 'Culture', 185, 24),
#  (134, 'Infrared', 183, 20),
#  (323, 'Serbo-Croatian', 183, 22),
#  (296, 'LaserDisc', 182, 50),
#  (333, 'Diarrhea', 181, 21),
#  (39, 'Oklahoma_City', 179, 82),
#  (71, 'Political_corruption', 179, 57),
#  (310, 'Apollo', 179, 52),
#  (22, 'Symbiosis', 175, 23),
#  (49, 'Hydrogen', 174, 60),
#  (50, 'Space_Race', 173, 70),
#  (29, 'Human_Development_Index', 168, 38),
#  (109, 'Identity_(social_science)', 168, 21),
#  (237, 'Chinese_characters', 168, 56),
#  (69, 'Bern', 164, 52),
#  (45, 'Internet_service_provider', 161, 21),
#  (270, 'Galicia_(Spain)', 159, 50),
#  (148, 'General_Electric', 158, 16),
#  (19, 'Institute_of_technology', 154, 77),
#  (127, 'Mesozoic', 153, 16),
#  (434, 'Montana', 149, 44),
#  (35, 'Warsaw_Pact', 146, 23),
#  (441, 'Matter', 142, 29),
#  (25, 'Iranian_languages', 140, 21),
#  (26, 'Lighting', 140, 57),
#  (440, 'Myocardial_infarction', 126, 26),
#  (106, 'England_national_football_team', 119, 12),
#  (111, 'Communication', 117, 12),
#  (125, 'Federal_Aviation_Administration', 109, 12),
#  (133, 'Great_Plains', 108, 13),
#  (99, 'Immunology', 85, 18),
#  (137, 'Digestion', 85, 18),
#  (115, 'Animal', 79, 17),
#  (372, 'Central_Intelligence_Agency', 65, 16),
#  (104, 'Imamah_(Shia_doctrine)', 64, 14),
#  (155, 'Order_of_the_British_Empire', 63, 13),
#  (102, 'Letter_case', 55, 12),
#  (117, 'Race_and_ethnicity_in_the_United_States_Census', 52, 12),
#  (112, 'Grape', 48, 10),
#  (105, 'Pitch_(music)', 36, 10)]

# %%
category_indices = [0, 1, 168, 6, 152, 438]

# %%
from dataclasses import dataclass
from typing import Optional

@dataclass
class Question:
    question: str
    context_index: int
    embedding: Optional[torch.tensor] = None
    transformed_embedding: Optional[torch.tensor] = None

@dataclass
class Context:
    context: str
    context_index: int
    embedding: Optional[torch.tensor] = None
    transformed_embedding: Optional[torch.tensor] = None

@dataclass
class DataCollection:
    questions: list[Question]
    contexts: list[Context]
    metadata: dict

# %%
for index in category_indices:
    question_collection: list[Question] = []
    context_collection: list[Context] = []
    for i, context in enumerate(train_data['data'][index]['paragraphs']):
        context_collection.append(Context(context=context['context'], context_index=i))
        for question in context['qas']:
            if question['is_impossible']:
                continue
            question_collection.append(Question(question=question['question'], context_index=i))
        # print(i, context['qas'][0])
        
    data_collection = DataCollection(
        questions=question_collection,
        contexts=context_collection,
        metadata={
            "description": "Raw question data",
            "category":train_data['data'][index]['title']
        }
    )

    with open(f"data/raw/{train_data['data'][index]['title']}-base.pkl", 'wb') as file:
        pickle.dump(data_collection, file)

# %%
question_collection: list[Question] = []
context_collection: list[Context] = []

# %%
train_data['data'][6]['paragraphs'][0]
# Out:
# {'qas': [{'question': 'In what year did the earthquake in Sichuan occur?',
#    'id': '56cdca7862d2951400fa6826',
#    'answers': [{'text': '2008', 'answer_start': 4}],
#    'is_impossible': False},
#   {'question': 'What was the earthquake named?',
#    'id': '56cdca7862d2951400fa6827',
#    'answers': [{'text': 'the Great Sichuan earthquake', 'answer_start': 31}],
#    'is_impossible': False},
#   {'question': 'How many people were killed as a result?',
#    'id': '56cdca7862d2951400fa6828',
#    'answers': [{'text': '69,197', 'answer_start': 206}],
#    'is_impossible': False},
#   {'question': 'What year did the Sichuan earthquake take place?',
#    'id': '56d4f9902ccc5a1400d833c0',
#    'answers': [{'text': '2008', 'answer_start': 4}],
#    'is_impossible': False},
#   {'question': 'What did the quake measure?',
#    'id': '56d4f9902ccc5a1400d833c1',
#    'answers': [{'text': '8.0 Ms and 7.9 Mw', 'answer_start': 73}],
#    'is_impossible': False},
#   {'question': 'What day did the earthquake occur?',
#    'id': '56d4f9902ccc5a1400d833c2',
#    'answers': [{'text': 'May 12', 'answer_start': 171}],
#    'is_impossible': False},
#   {'question': 'What time of the day did the quake happen?',
#    'id': '56d4f9902ccc5a1400d833c3',
#    'answers': [{'text': '02:28:01 PM China Standard Time',
#      'answer_start': 108}],
#    'is_impossible': False},
#   {'question': 'How many people died?',
#    'id': '56d4f9902ccc5a1400d833c4',
#    'answers': [{'text': '69,197', 'answer_start': 206}],
#    'is_impossible': False}],
#  'context': 'The 2008 Sichuan earthquake or the Great Sichuan earthquake, measured at 8.0 Ms and 7.9 Mw, and occurred at 02:28:01 PM China Standard Time at epicenter (06:28:01 UTC) on May 12 in Sichuan province, killed 69,197 people and left 18,222 missing.'}

# %%
for i, context in enumerate(train_data['data'][category_index]['paragraphs']):
    context_collection.append(Context(context=context['context'], context_index=i))
    for question in context['qas']:
        if question['is_impossible']:
            continue
        question_collection.append(Question(question=question['question'], context_index=i))
    print(i, context['qas'][0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 for i, context in enumerate(train_data['data'][category_index]['paragraphs']):
#       2     context_collection.append(Context(context=context['context'], context_index=i))
#       3     for question in context['qas']:
#
# NameError: name 'category_index' is not defined

# %%
data_collection = DataCollection(
    questions=question_collection,
    contexts=context_collection,
    metadata={
        "description": "Raw question data",
        "category":train_data['data'][category_index]['title']
    }
)

# %%
data_collection.metadata
# Out:
# {'description': 'Raw question data', 'category': 'Beyoncé'}
